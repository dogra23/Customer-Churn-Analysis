# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\SHIVAM\Customer-Churn-Analysis\data\Churn_master.csv")

# %%
df.head()
# Out:
#   customer_ID  gender senior_citizen partner dependents  tenure  \
# 0  7590-VHVEG  Female             No     Yes         No       1
# 1  5575-GNVDE    Male             No      No         No      34
# 2  3668-QPYBK    Male             No      No         No       2
# 3  7795-CFOCW    Male             No      No         No      45
# 4  9237-HQITU  Female             No      No         No       2
#
#          contract             payment_method paperless_billing  \
# 0  Month-to-month           Electronic check               Yes
# 1        One year               Mailed check                No
# 2  Month-to-month               Mailed check               Yes
# 3        One year  Bank transfer (automatic)                No
# 4  Month-to-month           Electronic check               Yes
#
#    monthly_charges  ...  Online Backup Premium Tech Support Streaming TV  \
# 0            29.85  ...            Yes                   No           No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_ID           7032 non-null   object
#  1   gender                7032 non-null   object
#  2   senior_citizen        7032 non-null   object
#  3   partner               7032 non-null   object
#  4   dependents            7032 non-null   object
#  5   tenure                7032 non-null   int64
#  6   contract              7032 non-null   object
#  7   payment_method        7032 non-null   object
#  8   paperless_billing     7032 non-null   object
#  9   monthly_charges       7032 non-null   float64
#  10  total_charges         7032 non-null   float64
#  11  Internet Type         5512 non-null   object
#  12  Online Security       7032 non-null   object
#  13  Online Backup         7032 non-null   object
#  14  Premium Tech Support  7032 non-null   object
# ...

# %%
df.shape
# Out:
# (7032, 23)

# %%
df['churn'].value_counts()
# Out:
# churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
churn_rate = df['churn'].value_counts(normalize=True)*100

# %%
churn_rate
# Out:
# churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %%
df['contract'].value_counts(normalize=True)*100
# Out:
# contract
# Month-to-month    55.105233
# Two year          23.961889
# One year          20.932878
# Name: proportion, dtype: float64
